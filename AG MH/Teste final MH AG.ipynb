# %% [markdown]
# Função para abrir o arquivo e imprimir os pontos

# %%
# Abre o arquivo em modo de leitura
nome_arquivo = "xqf131.tsp"
try:
    with open(nome_arquivo, 'r') as arquivo:
        # Lê e imprime o conteúdo do arquivo
        conteudo = arquivo.read()
        print(conteudo)
except FileNotFoundError:
    print(f"O arquivo '{nome_arquivo}' não foi encontrado.")
except Exception as e:
    print(f"Ocorreu um erro: {str(e)}")
# Out:
# NAME : xqf131
# COMMENT : Bonn VLSI data set with 131 points
# COMMENT : Uni Bonn, Research Institute for Discrete Math
# COMMENT : Contributed by Andre Rohe
# TYPE : TSP
# DIMENSION : 131
# EDGE_WEIGHT_TYPE : EUC_2D
# NODE_COORD_SECTION
# 1 0 13
# 2 0 26
# 3 0 27
# 4 0 39
# 5 2 0
# 6 5 13
# 7 5 19
# 8 5 25
# 9 5 31
# 10 5 37
# 11 5 43
# 12 5 8
# 13 8 0
# 14 9 10
# 15 10 10
# 16 11 10
# 17 12 10
# 18 12 5
# 19 15 13
# 20 15 19
# 21 15 25
# 22 15 31
# 23 15 37
# 24 15 43
# 25 15 8
# 26 18 11
# 27 18 13
# 28 18 15
# 29 18 17
# 30 18 19
# 31 18 21
# 32 18 23
# 33 18 25
# 34 18 27
# 35 18 29
# 36 18 31
# 37 18 33
# 38 18 35
# 39 18 37
# 40 18 39
# 41 18 41
# 42 18 42
# 43 18 44
# 44 18 45
# 45 25 11
# 46 25 15
# 47 25 22
# 48 25 23
# 49 25 24
# 50 25 26
# 51 25 28
# 52 25 29
# 53 25 9
# 54 28 16
# 55 28 20
# 56 28 28
# 57 28 30
# 58 28 34
# 59 28 40
# 60 28 43
# 61 28 47
# 62 32 26
# 63 32 31
# 64 33 15
# 65 33 26
# 66 33 29
# 67 33 31
# 68 34 15
# 69 34 26
# 70 34 29
# 71 34 31
# 72 34 38
# 73 34 41
# 74 34 5
# 75 35 17
# 76 35 31
# 77 38 16
# 78 38 20
# 79 38 30
# 80 38 34
# 81 40 22
# 82 41 23
# 83 41 32
# 84 41 34
# 85 41 35
# 86 41 36
# 87 48 22
# 88 48 27
# 89 48 6
# 90 51 45
# 91 51 47
# 92 56 25
# 93 57 12
# 94 57 25
# 95 57 44
# 96 61 45
# 97 61 47
# 98 63 6
# 99 64 22
# 100 71 11
# 101 71 13
# 102 71 16
# 103 71 45
# 104 71 47
# 105 74 12
# 106 74 16
# 107 74 20
# 108 74 24
# 109 74 29
# 110 74 35
# 111 74 39
# 112 74 6
# 113 77 21
# 114 78 10
# 115 78 32
# 116 78 35
# 117 78 39
# 118 79 10
# 119 79 33
# 120 79 37
# 121 80 10
# 122 80 41
# 123 80 5
# 124 81 17
# 125 84 20
# 126 84 24
# 127 84 29
# 128 84 34
# 129 84 38
# 130 84 6
# 131 107 27
# EOF

# %% [markdown]
# Instalar biblioteca matplot

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\thamy\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: C:\Users\thamy\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# Função para ler o arquivo e salvar os pontos dados. Retorna o parâmetro "pontos"

# %%
import matplotlib.pyplot as plt

def ler_arquivo_tsp(xqf131):
    pontos = []
    with open(nome_arquivo, 'r') as arquivo:
        lendo_pontos = False
        for linha in arquivo:
            linha = linha.strip()
            if lendo_pontos:
                if linha == "EOF":
                    break
                numero, x, y = map(float, linha.split())
                pontos.append((x, y))
            elif linha == "NODE_COORD_SECTION":
                lendo_pontos = True
    return pontos

# %% [markdown]
# Função para plotar um gráfico com os pontos que foram salvos anteriormente

# %%
def plotar_pontos(pontos):
    x, y = zip(*pontos)
    plt.scatter(x, y, marker='o', color='b', label='Pontos')
    plt.xlabel('Coordenada X')
    plt.ylabel('Coordenada Y')
    plt.title('Pontos do Arquivo TSP')
    plt.legend()
    plt.grid(True)
    plt.show()

# Nome do arquivo TSP
nome_arquivo = 'xqf131.tsp'

# Ler as coordenadas dos pontos
pontos = ler_arquivo_tsp(nome_arquivo)

# Plotar os pontos em um gráfico
plotar_pontos(pontos)

# %% [markdown]
# ***Sobre o algoritmo genético:

# %% [markdown]
# Inicialização: É a criação de uma população inicial de modelos, em que cada solução representa um indivíduo na população. Cada rota criada é uma solução, e são usadas heurísticas para descobrir uma rota.

# %% [markdown]
# Cálculo da fitness: Função de avaliação, que mede o quão adaptado está o indivíduo ao ambiente.  Em termos computacionais, esta medida indica o quão bem um dado candidato à solução (indivíduo) é
# capaz de resolver o problema (ambiente). Em problemas de otimização de roteamento, o fitness pode ser o somatório da distância total percorrida, a fim de descobrir a menor distância possível para percorrer os 131 pontos dados.

# %% [markdown]
# Seleção: Processo de escolha que usualmente seleciona os indivíduos mais adaptados (que apresentam um maior fitness), para participarem do processo de reprodução. Um dos métodos mais utilizados é a seleção por torneio, que é recomendada quando há uma grande diferença relativa no valor do fitness dos indivíduos.

# %% [markdown]
# --- INICIALIZANDO O CÓDIGO ---

# %% [markdown]
# Função para ler o arquivo e salvar as coordenadas. Retorna o parâmetro "cidades"

# %%
import random

def ler_arquivo_tsp(nome_arquivo):
    cidades = []
    with open(nome_arquivo, 'r') as arquivo:
        lendo_coord = False
        for linha in arquivo:
            linha = linha.strip()
            if linha.startswith("NODE_COORD_SECTION"):
                lendo_coord = True
            elif linha.startswith("EOF"):
                break
            elif lendo_coord:
                partes = linha.split()
                cidade_id = int(partes[0])
                x = float(partes[1])
                y = float(partes[2])
                cidades.append((cidade_id, x, y))
    return cidades

# %% [markdown]
# Função para criar a população inicial de cromossomos, formada a partir de indivíduos aleatoriamente criados. Utiliza as coordenadas das cidades criadas anteriormente. Essa função foi utilizada pois a inicialização da população determina o processo de criação dos indivíduos para o primeiro ciclo do algoritmo. Dessa forma, foi escolhido o valor 100 para criar 100 diferentes rotas para atender os 131 pontos.

# %%
def criar_populacao_inicial(cidades, tamanho_populacao):
    # Crie indivíduos como permutações aleatórias das cidades
    populacao = []
    cidades_sem_origem = cidades[1:]  # Exclua a cidade de origem
    for _ in range(tamanho_populacao):
        cromossomo = random.sample(cidades_sem_origem, len(cidades_sem_origem))
        cromossomo.insert(0, cidades[0])  # Adicione a cidade de origem no início
        populacao.append(cromossomo)
    return populacao

# Substitua "exemplo.tsp" pelo nome do seu arquivo .tsp
nome_do_arquivo_tsp = "xqf131.tsp"

# Leitura das coordenadas das cidades do arquivo .tsp
cidades = ler_arquivo_tsp(nome_do_arquivo_tsp)

# Inicialização da população
tamanho_populacao = 100  # Tamanho da população inicial
populacao_inicial = criar_populacao_inicial(cidades, tamanho_populacao)
#print (populacao_inicial)

# Agora, a variável "populacao_inicial" contém a população inicial de cromossomos

# %% [markdown]
# ---CÁLCULO DA FITNESS---

# %% [markdown]
# Função para calcular a distância euclidiana entre duas cidades

# %%
import random
import math
def calcular_distancia(cidade1, cidade2):
    # Cálculo da distância euclidiana entre duas cidades
    x1, y1 = cidade1[1], cidade1[2]
    x2, y2 = cidade2[1], cidade2[2]
    return math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

# %% [markdown]
# Função para calcular a aptidão do indivíduo (nesse caso, cada cidade é um cromossomo, e a aptidão é dada pela soma das distâncias entre duas cidades). Essa função foi utilizada para avaliar quão boa é uma solução candidata (cromossomo) em relação ao problema. Ou seja, a função de aptidão avalia o desempenho de um cromossomo.

# %%
def calcular_aptidao(cromossomo):
    # Calcula a distância total percorrida no TSP
    distancia_total = 0.0
    for i in range(len(cromossomo) - 1):
        cidade_atual = cromossomo[i]
        proxima_cidade = cromossomo[i + 1]
        distancia_total += calcular_distancia(cidade_atual, proxima_cidade)
    
    # Adicione a distância de retorno à cidade de origem
    distancia_total += calcular_distancia(cromossomo[-1], cromossomo[0])
    
    # Retornamos a distância total
    return distancia_total

# Substitua "exemplo.tsp" pelo nome do seu arquivo .tsp
nome_do_arquivo_tsp = "xqf131.tsp"

# Leitura das coordenadas das cidades do arquivo .tsp
cidades = ler_arquivo_tsp(nome_do_arquivo_tsp)

# Cálculo da aptidão para o cromossomo de exemplo
for cromossomo_exemplo in populacao_inicial:
    aptidao_exemplo = calcular_aptidao(cromossomo_exemplo)
    #print("{:.2f}".format(aptidao_exemplo))

# Agora, a variável "aptidao_exemplo" contém a aptidão do cromossomo de exemplo

# %% [markdown]
# ---SELEÇÃO---

# %% [markdown]
# Função para realizar a seleção utilizando o método do torneio, retornando o vencedor (no caso, o cromossomo com melhor aptidão). Essa função foi usada para selecionar indivíduos da população atual que serão os pais das próximas gerações. A função retorna o vencedor de cada torneio (pais da próxima geração)

# %%
import random
import math
import matplotlib.pyplot as plt

# Função para realizar o torneio de seleção
def selecao_torneio(populacao, tamanho_torneio):
    torneio = random.sample(populacao, tamanho_torneio)
    vencedor_torneio = min(torneio, key=calcular_aptidao)
    return vencedor_torneio

# %% [markdown]
# Função para realizar o crossover ordenado entre dois pais.  Essa função foi usada para realizar o processo de cruzamento (crossover) entre dois pais a fim de criar um filho, ou seja, para ir melhorando a aptidão dos cromossomos e ir gerando melhores filhos (com melhor aptidão) com o passar das gerações. A função retorna o filho que herdou as melhores características dos seus pais.

# %%
# Função para realizar o crossover ordenado entre dois pais
def crossover_ordenado(pai1, pai2):
    ponto_corte1, ponto_corte2 = sorted(random.sample(range(len(pai1)), 2))
    filho = [-1] * len(pai1)
    filho[ponto_corte1:ponto_corte2 + 1] = pai1[ponto_corte1:ponto_corte2 + 1]
    restantes_genes = [gene for gene in pai2 if gene not in filho]
    indice_insercao = 0
    for i in range(len(filho)):
        if filho[i] == -1:
            filho[i] = restantes_genes[indice_insercao]
            indice_insercao += 1
    return filho

# %% [markdown]
# Função para realizar a mutação de um cromossomo. Essa função foi usada para atuar sobre os cromossomos gerados pelo crossover, permitindo que valores de genes, eventualmente perdidos durante o processo de evolução, possam retornar à população, possibilitando a avaliação dos mesmos em novos contextos populacionais. Por outro lado, tem-se que este operador também proporciona o surgimento de novos genes, não presentes nas populações iniciais, contribuindo para a diversidade da população. O operador de mutação introduz um certo grau de aleatoriedade no algoritmo genético, permitindo que mais pontos do espaço de busca sejam efetivamente avaliados.

# %%
# Função para realizar a mutação de um cromossomo
def mutacao(cromossomo, taxa_mutacao):
    if random.random() < taxa_mutacao:
        indice1, indice2 = random.sample(range(len(cromossomo)), 2)
        cromossomo[indice1], cromossomo[indice2] = cromossomo[indice2], cromossomo[indice1]

# %% [markdown]
# Função para criar a próxima geração com elitismo. Essa função foi usada como técnica de substituição de indivíduos para evitar que a melhor solução encontrada até o momento não seja perdida ao longo de várias gerações até que um critério de parada seja atingido. Ou seja, o parâmetro para gerações não foi definido pois não foi possível prever com antecedência a quantidade de gerações necessárias para encontrar uma solução factível, portanto, foi criado um loop com o critério de parada usando o fator de número máximo de gerações sem melhoria para que o algoritmo continue evoluindo até que o critério de parada seja atingido. Para o critério de parada "max_iter_sem_melhoria=200", foi utilizado o parâmetro "iter_sem_melhoria", de forma que o algoritmo pare se em 200 gerações consecutivas não resultar em uma melhoria de solução, evitando que o algoritmo continue indefinidamente sem fazer progresso. O parâmetro "tamanho_populacao=2000" indica que há 2000 indivíduos (rotas) diferentes para compor a geração. O parâmetro "tamanho_torneio=200" indica a quantidade de indivíduos que competem na seleção, favorecendo os que tem maior aptidão. E o parâmetro "taxa_mutacao=0.05" indica que para cada gene em um cromossomo há uma probabilidade de 5% de que ocorra uma mutação. Ao final, printa a melhor rota encontrada e plota seu gráfico.

# %%
# Função para criar a próxima geração com elitismo
def criar_proxima_geracao(populacao, tamanho_torneio, taxa_mutacao):
    proxima_geracao = []
    melhor_cromossomo = min(populacao, key=calcular_aptidao)
    proxima_geracao.append(melhor_cromossomo)  # Elitismo: mantém o melhor cromossomo
    while len(proxima_geracao) < len(populacao):
        pai1 = selecao_torneio(populacao, tamanho_torneio)
        pai2 = selecao_torneio(populacao, tamanho_torneio)
        filho = crossover_ordenado(pai1, pai2)
        mutacao(filho, taxa_mutacao)
        proxima_geracao.append(filho)
    return proxima_geracao

# Substitua "exemplo.tsp" pelo nome do seu arquivo .tsp
nome_do_arquivo_tsp = "xqf131.tsp"

# Leitura das coordenadas das cidades do arquivo .tsp
cidades = ler_arquivo_tsp(nome_do_arquivo_tsp)

# Parâmetros do algoritmo genético
tamanho_populacao = 2000
tamanho_torneio = 200
taxa_mutacao = 0.05

# Variáveis para controle de critério de parada automático
max_iter_sem_melhoria = 200  # Número máximo de gerações sem melhoria
melhor_custo_atual = float('inf')
iter_sem_melhoria = 0

# Inicialização da população
populacao = criar_populacao_inicial(cidades, tamanho_populacao)

# Execução do algoritmo genético
melhores_rotas = []

while iter_sem_melhoria < max_iter_sem_melhoria:
    populacao = criar_proxima_geracao(populacao, tamanho_torneio, taxa_mutacao)
    melhor_cromossomo = min(populacao, key=calcular_aptidao)
    melhor_custo = calcular_aptidao(melhor_cromossomo)

    if melhor_custo < melhor_custo_atual:
        melhor_custo_atual = melhor_custo
        iter_sem_melhoria = 0
    else:
        iter_sem_melhoria += 1

    melhores_rotas.append(melhor_custo_atual)

    print(f"Geração: {len(melhores_rotas)}, Melhor custo atual: {melhor_custo_atual:.2f}")

# Encontrando a melhor rota no final das gerações
melhor_cromossomo_final = min(populacao, key=calcular_aptidao)
melhor_aptidao_final = calcular_aptidao(melhor_cromossomo_final)

# Imprimir a melhor rota e a aptidão
print("Melhor Rota Encontrada:")
print("Rota:", melhor_cromossomo_final)
print("Aptidão:", melhor_aptidao_final)

# Plotar a melhor rota encontrada
melhor_rota_x, melhor_rota_y = zip(*[(cidade[1], cidade[2]) for cidade in melhor_cromossomo_final])
melhor_rota_x = list(melhor_rota_x) + [melhor_rota_x[0]]
melhor_rota_y = list(melhor_rota_y) + [melhor_rota_y[0]]

plt.figure(figsize=(10, 6))
plt.plot(melhor_rota_x, melhor_rota_y, marker='o', linestyle='-')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')
plt.title('Melhor Rota Encontrada')
plt.grid(True)
plt.show()
# Out:
# Geração: 1, Melhor custo atual: 3605.75
# Geração: 2, Melhor custo atual: 3421.73
# Geração: 3, Melhor custo atual: 3208.99
# Geração: 4, Melhor custo atual: 3106.49
# Geração: 5, Melhor custo atual: 2953.06
# Geração: 6, Melhor custo atual: 2781.65
# Geração: 7, Melhor custo atual: 2684.70
# Geração: 8, Melhor custo atual: 2605.06
# Geração: 9, Melhor custo atual: 2535.33
# Geração: 10, Melhor custo atual: 2465.03
# Geração: 11, Melhor custo atual: 2419.40
# Geração: 12, Melhor custo atual: 2368.76
# Geração: 13, Melhor custo atual: 2284.98
# Geração: 14, Melhor custo atual: 2205.51
# Geração: 15, Melhor custo atual: 2161.17
# Geração: 16, Melhor custo atual: 2108.46
# Geração: 17, Melhor custo atual: 2075.76
# Geração: 18, Melhor custo atual: 2021.94
# Geração: 19, Melhor custo atual: 1999.13
# Geração: 20, Melhor custo atual: 1970.22
# Geração: 21, Melhor custo atual: 1948.11
# Geração: 22, Melhor custo atual: 1919.20
# Geração: 23, Melhor custo atual: 1894.16
# Geração: 24, Melhor custo atual: 1862.29
# Geração: 25, Melhor custo atual: 1830.59
# Geração: 26, Melhor custo atual: 1783.82
# Geração: 27, Melhor custo atual: 1727.89
# Geração: 28, Melhor custo atual: 1714.85
# Geração: 29, Melhor custo atual: 1698.67
# Geração: 30, Melhor custo atual: 1671.90
# Geração: 31, Melhor custo atual: 1642.59
# Geração: 32, Melhor custo atual: 1636.08
# Geração: 33, Melhor custo atual: 1629.68
# Geração: 34, Melhor custo atual: 1614.87
# Geração: 35, Melhor custo atual: 1598.73
# Geração: 36, Melhor custo atual: 1581.96
# Geração: 37, Melhor custo atual: 1579.04
# Geração: 38, Melhor custo atual: 1537.25
# Geração: 39, Melhor custo atual: 1531.22
# Geração: 40, Melhor custo atual: 1523.30
# Geração: 41, Melhor custo atual: 1520.81
# Geração: 42, Melhor custo atual: 1509.49
# Geração: 43, Melhor custo atual: 1494.59
# Geração: 44, Melhor custo atual: 1491.39
# Geração: 45, Melhor custo atual: 1482.65
# Geração: 46, Melhor custo atual: 1474.20
# Geração: 47, Melhor custo atual: 1465.59
# Geração: 48, Melhor custo atual: 1457.80
# Geração: 49, Melhor custo atual: 1448.79
# Geração: 50, Melhor custo atual: 1417.55
# Geração: 51, Melhor custo atual: 1401.73
# Geração: 52, Melhor custo atual: 1374.69
# Geração: 53, Melhor custo atual: 1359.01
# Geração: 54, Melhor custo atual: 1345.11
# Geração: 55, Melhor custo atual: 1334.37
# Geração: 56, Melhor custo atual: 1323.91
# Geração: 57, Melhor custo atual: 1307.37
# Geração: 58, Melhor custo atual: 1292.97
# Geração: 59, Melhor custo atual: 1280.44
# Geração: 60, Melhor custo atual: 1273.91
# Geração: 61, Melhor custo atual: 1267.05
# Geração: 62, Melhor custo atual: 1266.93
# Geração: 63, Melhor custo atual: 1262.82
# Geração: 64, Melhor custo atual: 1259.73
# Geração: 65, Melhor custo atual: 1250.83
# Geração: 66, Melhor custo atual: 1240.39
# Geração: 67, Melhor custo atual: 1232.87
# Geração: 68, Melhor custo atual: 1229.63
# Geração: 69, Melhor custo atual: 1227.09
# Geração: 70, Melhor custo atual: 1226.00
# Geração: 71, Melhor custo atual: 1224.81
# Geração: 72, Melhor custo atual: 1222.98
# Geração: 73, Melhor custo atual: 1220.09
# Geração: 74, Melhor custo atual: 1217.37
# Geração: 75, Melhor custo atual: 1214.52
# Geração: 76, Melhor custo atual: 1213.01
# Geração: 77, Melhor custo atual: 1212.45
# Geração: 78, Melhor custo atual: 1211.43
# Geração: 79, Melhor custo atual: 1211.43
# Geração: 80, Melhor custo atual: 1208.92
# Geração: 81, Melhor custo atual: 1208.92
# Geração: 82, Melhor custo atual: 1208.92
# Geração: 83, Melhor custo atual: 1208.92
# Geração: 84, Melhor custo atual: 1208.92
# Geração: 85, Melhor custo atual: 1208.92
# Geração: 86, Melhor custo atual: 1208.92
# Geração: 87, Melhor custo atual: 1207.95
# Geração: 88, Melhor custo atual: 1204.95
# Geração: 89, Melhor custo atual: 1202.44
# Geração: 90, Melhor custo atual: 1200.79
# Geração: 91, Melhor custo atual: 1200.68
# Geração: 92, Melhor custo atual: 1200.68
# Geração: 93, Melhor custo atual: 1185.28
# Geração: 94, Melhor custo atual: 1183.55
# Geração: 95, Melhor custo atual: 1182.76
# Geração: 96, Melhor custo atual: 1182.30
# Geração: 97, Melhor custo atual: 1175.85
# Geração: 98, Melhor custo atual: 1173.75
# Geração: 99, Melhor custo atual: 1170.93
# Geração: 100, Melhor custo atual: 1166.91
# Geração: 101, Melhor custo atual: 1166.10
# Geração: 102, Melhor custo atual: 1165.59
# Geração: 103, Melhor custo atual: 1159.71
# Geração: 104, Melhor custo atual: 1157.07
# Geração: 105, Melhor custo atual: 1153.40
# Geração: 106, Melhor custo atual: 1150.03
# Geração: 107, Melhor custo atual: 1148.90
# Geração: 108, Melhor custo atual: 1143.73
# Geração: 109, Melhor custo atual: 1143.38
# Geração: 110, Melhor custo atual: 1143.38
# Geração: 111, Melhor custo atual: 1143.38
# Geração: 112, Melhor custo atual: 1143.38
# Geração: 113, Melhor custo atual: 1143.38
# Geração: 114, Melhor custo atual: 1134.21
# Geração: 115, Melhor custo atual: 1134.21
# Geração: 116, Melhor custo atual: 1132.19
# Geração: 117, Melhor custo atual: 1129.98
# Geração: 118, Melhor custo atual: 1126.61
# Geração: 119, Melhor custo atual: 1114.63
# Geração: 120, Melhor custo atual: 1114.63
# Geração: 121, Melhor custo atual: 1114.63
# Geração: 122, Melhor custo atual: 1114.63
# Geração: 123, Melhor custo atual: 1110.62
# Geração: 124, Melhor custo atual: 1109.26
# Geração: 125, Melhor custo atual: 1099.92
# Geração: 126, Melhor custo atual: 1092.41
# Geração: 127, Melhor custo atual: 1089.18
# Geração: 128, Melhor custo atual: 1089.18
# Geração: 129, Melhor custo atual: 1089.18
# Geração: 130, Melhor custo atual: 1086.82
# Geração: 131, Melhor custo atual: 1086.09
# Geração: 132, Melhor custo atual: 1085.19
# Geração: 133, Melhor custo atual: 1085.19
# Geração: 134, Melhor custo atual: 1084.65
# Geração: 135, Melhor custo atual: 1084.65
# Geração: 136, Melhor custo atual: 1077.35
# Geração: 137, Melhor custo atual: 1074.71
# Geração: 138, Melhor custo atual: 1072.38
# Geração: 139, Melhor custo atual: 1072.38
# Geração: 140, Melhor custo atual: 1072.38
# Geração: 141, Melhor custo atual: 1072.38
# Geração: 142, Melhor custo atual: 1067.28
# Geração: 143, Melhor custo atual: 1067.28
# Geração: 144, Melhor custo atual: 1067.05
# Geração: 145, Melhor custo atual: 1062.79
# Geração: 146, Melhor custo atual: 1058.81
# Geração: 147, Melhor custo atual: 1056.38
# Geração: 148, Melhor custo atual: 1056.38
# Geração: 149, Melhor custo atual: 1051.79
# Geração: 150, Melhor custo atual: 1049.31
# Geração: 151, Melhor custo atual: 1048.44
# Geração: 152, Melhor custo atual: 1048.44
# Geração: 153, Melhor custo atual: 1048.44
# Geração: 154, Melhor custo atual: 1048.44
# Geração: 155, Melhor custo atual: 1048.44
# Geração: 156, Melhor custo atual: 1048.30
# Geração: 157, Melhor custo atual: 1042.97
# Geração: 158, Melhor custo atual: 1038.67
# Geração: 159, Melhor custo atual: 1032.42
# Geração: 160, Melhor custo atual: 1031.38
# Geração: 161, Melhor custo atual: 1024.51
# Geração: 162, Melhor custo atual: 1023.47
# Geração: 163, Melhor custo atual: 1023.47
# Geração: 164, Melhor custo atual: 1023.47
# Geração: 165, Melhor custo atual: 1023.47
# Geração: 166, Melhor custo atual: 1023.35
# Geração: 167, Melhor custo atual: 1023.35
# Geração: 168, Melhor custo atual: 1023.35
# Geração: 169, Melhor custo atual: 1023.35
# Geração: 170, Melhor custo atual: 1023.35
# Geração: 171, Melhor custo atual: 1023.35
# Geração: 172, Melhor custo atual: 1023.35
# Geração: 173, Melhor custo atual: 1023.35
# Geração: 174, Melhor custo atual: 1023.35
# Geração: 175, Melhor custo atual: 1023.35
# Geração: 176, Melhor custo atual: 1023.35
# Geração: 177, Melhor custo atual: 1023.35
# Geração: 178, Melhor custo atual: 1023.35
# Geração: 179, Melhor custo atual: 1023.35
# Geração: 180, Melhor custo atual: 1023.35
# Geração: 181, Melhor custo atual: 1020.57
# Geração: 182, Melhor custo atual: 1020.57
# Geração: 183, Melhor custo atual: 1018.46
# Geração: 184, Melhor custo atual: 1018.46
# Geração: 185, Melhor custo atual: 1018.46
# Geração: 186, Melhor custo atual: 1018.46
# Geração: 187, Melhor custo atual: 1018.46
# Geração: 188, Melhor custo atual: 1018.46
# Geração: 189, Melhor custo atual: 1018.46
# Geração: 190, Melhor custo atual: 1018.46
# Geração: 191, Melhor custo atual: 1018.46
# Geração: 192, Melhor custo atual: 1018.46
# Geração: 193, Melhor custo atual: 1018.46
# Geração: 194, Melhor custo atual: 1012.32
# Geração: 195, Melhor custo atual: 1003.95
# Geração: 196, Melhor custo atual: 1001.87
# Geração: 197, Melhor custo atual: 1001.87
# Geração: 198, Melhor custo atual: 999.50
# Geração: 199, Melhor custo atual: 998.36
# Geração: 200, Melhor custo atual: 995.75
# Geração: 201, Melhor custo atual: 995.75
# Geração: 202, Melhor custo atual: 995.75
# Geração: 203, Melhor custo atual: 995.75
# Geração: 204, Melhor custo atual: 995.75
# Geração: 205, Melhor custo atual: 995.75
# Geração: 206, Melhor custo atual: 995.75
# Geração: 207, Melhor custo atual: 995.75
# Geração: 208, Melhor custo atual: 995.75
# Geração: 209, Melhor custo atual: 995.75
# Geração: 210, Melhor custo atual: 995.75
# Geração: 211, Melhor custo atual: 995.75
# Geração: 212, Melhor custo atual: 995.75
# Geração: 213, Melhor custo atual: 995.53
# Geração: 214, Melhor custo atual: 995.43
# Geração: 215, Melhor custo atual: 994.88
# Geração: 216, Melhor custo atual: 994.88
# Geração: 217, Melhor custo atual: 994.88
# Geração: 218, Melhor custo atual: 994.88
# Geração: 219, Melhor custo atual: 994.88
# Geração: 220, Melhor custo atual: 994.88
# Geração: 221, Melhor custo atual: 994.88
# Geração: 222, Melhor custo atual: 990.54
# Geração: 223, Melhor custo atual: 990.38
# Geração: 224, Melhor custo atual: 987.78
# Geração: 225, Melhor custo atual: 987.78
# Geração: 226, Melhor custo atual: 986.83
# Geração: 227, Melhor custo atual: 986.83
# Geração: 228, Melhor custo atual: 986.83
# Geração: 229, Melhor custo atual: 986.83
# Geração: 230, Melhor custo atual: 986.83
# Geração: 231, Melhor custo atual: 986.83
# Geração: 232, Melhor custo atual: 985.19
# Geração: 233, Melhor custo atual: 984.99
# Geração: 234, Melhor custo atual: 981.58
# Geração: 235, Melhor custo atual: 971.21
# Geração: 236, Melhor custo atual: 971.21
# Geração: 237, Melhor custo atual: 971.21
# Geração: 238, Melhor custo atual: 971.21
# Geração: 239, Melhor custo atual: 971.21
# Geração: 240, Melhor custo atual: 971.21
# Geração: 241, Melhor custo atual: 969.63
# Geração: 242, Melhor custo atual: 969.63
# Geração: 243, Melhor custo atual: 969.63
# Geração: 244, Melhor custo atual: 969.63
# Geração: 245, Melhor custo atual: 969.63
# Geração: 246, Melhor custo atual: 969.63
# Geração: 247, Melhor custo atual: 969.63
# Geração: 248, Melhor custo atual: 969.63
# Geração: 249, Melhor custo atual: 969.63
# Geração: 250, Melhor custo atual: 969.63
# Geração: 251, Melhor custo atual: 969.63
# Geração: 252, Melhor custo atual: 969.63
# Geração: 253, Melhor custo atual: 969.63
# Geração: 254, Melhor custo atual: 969.63
# Geração: 255, Melhor custo atual: 969.63
# Geração: 256, Melhor custo atual: 969.63
# Geração: 257, Melhor custo atual: 969.63
# Geração: 258, Melhor custo atual: 969.63
# Geração: 259, Melhor custo atual: 969.24
# Geração: 260, Melhor custo atual: 969.02
# Geração: 261, Melhor custo atual: 968.48
# Geração: 262, Melhor custo atual: 968.48
# Geração: 263, Melhor custo atual: 968.48
# Geração: 264, Melhor custo atual: 968.48
# Geração: 265, Melhor custo atual: 968.48
# Geração: 266, Melhor custo atual: 968.48
# Geração: 267, Melhor custo atual: 967.95
# Geração: 268, Melhor custo atual: 967.95
# Geração: 269, Melhor custo atual: 967.95
# Geração: 270, Melhor custo atual: 967.95
# Geração: 271, Melhor custo atual: 967.95
# Geração: 272, Melhor custo atual: 967.95
# Geração: 273, Melhor custo atual: 967.95
# Geração: 274, Melhor custo atual: 967.95
# Geração: 275, Melhor custo atual: 967.95
# Geração: 276, Melhor custo atual: 967.95
# Geração: 277, Melhor custo atual: 967.95
# Geração: 278, Melhor custo atual: 967.95
# Geração: 279, Melhor custo atual: 967.95
# Geração: 280, Melhor custo atual: 967.95
# Geração: 281, Melhor custo atual: 967.95
# Geração: 282, Melhor custo atual: 962.11
# Geração: 283, Melhor custo atual: 962.11
# Geração: 284, Melhor custo atual: 962.11
# Geração: 285, Melhor custo atual: 962.11
# Geração: 286, Melhor custo atual: 961.78
# Geração: 287, Melhor custo atual: 961.78
# Geração: 288, Melhor custo atual: 961.78
# Geração: 289, Melhor custo atual: 961.78
# Geração: 290, Melhor custo atual: 961.78
# Geração: 291, Melhor custo atual: 961.78
# Geração: 292, Melhor custo atual: 961.78
# Geração: 293, Melhor custo atual: 961.78
# Geração: 294, Melhor custo atual: 959.91
# Geração: 295, Melhor custo atual: 959.91
# Geração: 296, Melhor custo atual: 959.91
# Geração: 297, Melhor custo atual: 959.91
# Geração: 298, Melhor custo atual: 959.91
# Geração: 299, Melhor custo atual: 956.67
# Geração: 300, Melhor custo atual: 956.67
# Geração: 301, Melhor custo atual: 956.67
# Geração: 302, Melhor custo atual: 956.67
# Geração: 303, Melhor custo atual: 956.67
# Geração: 304, Melhor custo atual: 956.67
# Geração: 305, Melhor custo atual: 956.67
# Geração: 306, Melhor custo atual: 956.18
# Geração: 307, Melhor custo atual: 956.18
# Geração: 308, Melhor custo atual: 956.18
# Geração: 309, Melhor custo atual: 956.18
# Geração: 310, Melhor custo atual: 956.18
# Geração: 311, Melhor custo atual: 956.18
# Geração: 312, Melhor custo atual: 956.18
# Geração: 313, Melhor custo atual: 956.18
# Geração: 314, Melhor custo atual: 956.18
# Geração: 315, Melhor custo atual: 956.18
# Geração: 316, Melhor custo atual: 956.18
# Geração: 317, Melhor custo atual: 956.18
# Geração: 318, Melhor custo atual: 956.18
# Geração: 319, Melhor custo atual: 956.18
# Geração: 320, Melhor custo atual: 956.18
# Geração: 321, Melhor custo atual: 956.18
# Geração: 322, Melhor custo atual: 956.18
# Geração: 323, Melhor custo atual: 955.84
# Geração: 324, Melhor custo atual: 955.84
# Geração: 325, Melhor custo atual: 955.84
# Geração: 326, Melhor custo atual: 955.84
# Geração: 327, Melhor custo atual: 955.84
# Geração: 328, Melhor custo atual: 955.84
# Geração: 329, Melhor custo atual: 954.55
# Geração: 330, Melhor custo atual: 954.55
# Geração: 331, Melhor custo atual: 942.02
# Geração: 332, Melhor custo atual: 942.02
# Geração: 333, Melhor custo atual: 942.02
# Geração: 334, Melhor custo atual: 942.02
# Geração: 335, Melhor custo atual: 942.02
# Geração: 336, Melhor custo atual: 941.03
# Geração: 337, Melhor custo atual: 941.03
# Geração: 338, Melhor custo atual: 941.03
# Geração: 339, Melhor custo atual: 941.03
# Geração: 340, Melhor custo atual: 941.03
# Geração: 341, Melhor custo atual: 941.03
# Geração: 342, Melhor custo atual: 941.03
# Geração: 343, Melhor custo atual: 941.03
# Geração: 344, Melhor custo atual: 941.03
# Geração: 345, Melhor custo atual: 941.03
# Geração: 346, Melhor custo atual: 941.03
# Geração: 347, Melhor custo atual: 941.03
# Geração: 348, Melhor custo atual: 932.54
# Geração: 349, Melhor custo atual: 931.52
# Geração: 350, Melhor custo atual: 930.84
# Geração: 351, Melhor custo atual: 929.28
# Geração: 352, Melhor custo atual: 929.28
# Geração: 353, Melhor custo atual: 929.28
# Geração: 354, Melhor custo atual: 929.28
# Geração: 355, Melhor custo atual: 929.28
# Geração: 356, Melhor custo atual: 929.28
# Geração: 357, Melhor custo atual: 929.28
# Geração: 358, Melhor custo atual: 929.28
# Geração: 359, Melhor custo atual: 929.28
# Geração: 360, Melhor custo atual: 929.28
# Geração: 361, Melhor custo atual: 929.28
# Geração: 362, Melhor custo atual: 929.28
# Geração: 363, Melhor custo atual: 929.28
# Geração: 364, Melhor custo atual: 929.28
# Geração: 365, Melhor custo atual: 929.28
# Geração: 366, Melhor custo atual: 929.28
# Geração: 367, Melhor custo atual: 929.28
# Geração: 368, Melhor custo atual: 929.28
# Geração: 369, Melhor custo atual: 929.28
# Geração: 370, Melhor custo atual: 929.28
# Geração: 371, Melhor custo atual: 929.28
# Geração: 372, Melhor custo atual: 929.28
# Geração: 373, Melhor custo atual: 929.28
# Geração: 374, Melhor custo atual: 928.39
# Geração: 375, Melhor custo atual: 928.39
# Geração: 376, Melhor custo atual: 928.39
# Geração: 377, Melhor custo atual: 928.39
# Geração: 378, Melhor custo atual: 928.39
# Geração: 379, Melhor custo atual: 928.39
# Geração: 380, Melhor custo atual: 928.39
# Geração: 381, Melhor custo atual: 928.39
# Geração: 382, Melhor custo atual: 928.39
# Geração: 383, Melhor custo atual: 928.39
# Geração: 384, Melhor custo atual: 928.39
# Geração: 385, Melhor custo atual: 928.39
# Geração: 386, Melhor custo atual: 928.39
# Geração: 387, Melhor custo atual: 928.39
# Geração: 388, Melhor custo atual: 927.21
# Geração: 389, Melhor custo atual: 927.21
# Geração: 390, Melhor custo atual: 927.21
# Geração: 391, Melhor custo atual: 927.21
# Geração: 392, Melhor custo atual: 927.21
# Geração: 393, Melhor custo atual: 927.21
# Geração: 394, Melhor custo atual: 927.21
# Geração: 395, Melhor custo atual: 927.21
# Geração: 396, Melhor custo atual: 927.21
# Geração: 397, Melhor custo atual: 927.21
# Geração: 398, Melhor custo atual: 927.21
# Geração: 399, Melhor custo atual: 927.21
# Geração: 400, Melhor custo atual: 927.21
# Geração: 401, Melhor custo atual: 927.21
# Geração: 402, Melhor custo atual: 927.21
# Geração: 403, Melhor custo atual: 927.21
# Geração: 404, Melhor custo atual: 927.21
# Geração: 405, Melhor custo atual: 927.21
# Geração: 406, Melhor custo atual: 927.21
# Geração: 407, Melhor custo atual: 925.49
# Geração: 408, Melhor custo atual: 925.49
# Geração: 409, Melhor custo atual: 923.72
# Geração: 410, Melhor custo atual: 923.72
# Geração: 411, Melhor custo atual: 923.72
# Geração: 412, Melhor custo atual: 923.72
# Geração: 413, Melhor custo atual: 923.72
# Geração: 414, Melhor custo atual: 923.72
# Geração: 415, Melhor custo atual: 923.72
# Geração: 416, Melhor custo atual: 923.22
# Geração: 417, Melhor custo atual: 923.22
# Geração: 418, Melhor custo atual: 917.33
# Geração: 419, Melhor custo atual: 916.69
# Geração: 420, Melhor custo atual: 916.69
# Geração: 421, Melhor custo atual: 916.69
# Geração: 422, Melhor custo atual: 916.69
# Geração: 423, Melhor custo atual: 916.69
# Geração: 424, Melhor custo atual: 916.69
# Geração: 425, Melhor custo atual: 916.09
# Geração: 426, Melhor custo atual: 916.09
# Geração: 427, Melhor custo atual: 916.09
# Geração: 428, Melhor custo atual: 916.09
# Geração: 429, Melhor custo atual: 916.09
# Geração: 430, Melhor custo atual: 916.09
# Geração: 431, Melhor custo atual: 916.09
# Geração: 432, Melhor custo atual: 916.09
# Geração: 433, Melhor custo atual: 916.09
# Geração: 434, Melhor custo atual: 916.09
# Geração: 435, Melhor custo atual: 914.89
# Geração: 436, Melhor custo atual: 914.89
# Geração: 437, Melhor custo atual: 914.89
# Geração: 438, Melhor custo atual: 914.89
# Geração: 439, Melhor custo atual: 914.89
# Geração: 440, Melhor custo atual: 914.89
# Geração: 441, Melhor custo atual: 914.89
# Geração: 442, Melhor custo atual: 914.38
# Geração: 443, Melhor custo atual: 898.42
# Geração: 444, Melhor custo atual: 897.85
# Geração: 445, Melhor custo atual: 897.54
# Geração: 446, Melhor custo atual: 896.28
# Geração: 447, Melhor custo atual: 896.28
# Geração: 448, Melhor custo atual: 896.28
# Geração: 449, Melhor custo atual: 896.28
# Geração: 450, Melhor custo atual: 896.28
# Geração: 451, Melhor custo atual: 896.28
# Geração: 452, Melhor custo atual: 896.28
# Geração: 453, Melhor custo atual: 896.28
# Geração: 454, Melhor custo atual: 896.28
# Geração: 455, Melhor custo atual: 896.28
# Geração: 456, Melhor custo atual: 896.28
# Geração: 457, Melhor custo atual: 896.28
# Geração: 458, Melhor custo atual: 896.28
# Geração: 459, Melhor custo atual: 896.28
# Geração: 460, Melhor custo atual: 896.28
# Geração: 461, Melhor custo atual: 896.28
# Geração: 462, Melhor custo atual: 896.28
# Geração: 463, Melhor custo atual: 896.28
# Geração: 464, Melhor custo atual: 896.28
# Geração: 465, Melhor custo atual: 896.28
# Geração: 466, Melhor custo atual: 896.28
# Geração: 467, Melhor custo atual: 896.28
# Geração: 468, Melhor custo atual: 896.28
# Geração: 469, Melhor custo atual: 896.28
# Geração: 470, Melhor custo atual: 896.28
# Geração: 471, Melhor custo atual: 896.28
# Geração: 472, Melhor custo atual: 896.28
# Geração: 473, Melhor custo atual: 896.28
# Geração: 474, Melhor custo atual: 896.28
# Geração: 475, Melhor custo atual: 896.28
# Geração: 476, Melhor custo atual: 896.28
# Geração: 477, Melhor custo atual: 896.28
# Geração: 478, Melhor custo atual: 896.28
# Geração: 479, Melhor custo atual: 896.28
# Geração: 480, Melhor custo atual: 896.28
# Geração: 481, Melhor custo atual: 896.28
# Geração: 482, Melhor custo atual: 896.28
# Geração: 483, Melhor custo atual: 896.28
# Geração: 484, Melhor custo atual: 896.28
# Geração: 485, Melhor custo atual: 896.28
# Geração: 486, Melhor custo atual: 896.28
# Geração: 487, Melhor custo atual: 896.28
# Geração: 488, Melhor custo atual: 896.28
# Geração: 489, Melhor custo atual: 896.28
# Geração: 490, Melhor custo atual: 896.28
# Geração: 491, Melhor custo atual: 896.28
# Geração: 492, Melhor custo atual: 896.28
# Geração: 493, Melhor custo atual: 896.28
# Geração: 494, Melhor custo atual: 896.28
# Geração: 495, Melhor custo atual: 896.28
# Geração: 496, Melhor custo atual: 896.28
# Geração: 497, Melhor custo atual: 896.28
# Geração: 498, Melhor custo atual: 896.28
# Geração: 499, Melhor custo atual: 896.28
# Geração: 500, Melhor custo atual: 894.90
# Geração: 501, Melhor custo atual: 894.90
# Geração: 502, Melhor custo atual: 894.90
# Geração: 503, Melhor custo atual: 894.90
# Geração: 504, Melhor custo atual: 894.90
# Geração: 505, Melhor custo atual: 894.90
# Geração: 506, Melhor custo atual: 894.90
# Geração: 507, Melhor custo atual: 894.90
# Geração: 508, Melhor custo atual: 894.90
# Geração: 509, Melhor custo atual: 894.90
# Geração: 510, Melhor custo atual: 894.90
# Geração: 511, Melhor custo atual: 894.90
# Geração: 512, Melhor custo atual: 894.90
# Geração: 513, Melhor custo atual: 894.90
# Geração: 514, Melhor custo atual: 894.90
# Geração: 515, Melhor custo atual: 894.90
# Geração: 516, Melhor custo atual: 894.90
# Geração: 517, Melhor custo atual: 894.90
# Geração: 518, Melhor custo atual: 894.90
# Geração: 519, Melhor custo atual: 894.90
# Geração: 520, Melhor custo atual: 894.90
# Geração: 521, Melhor custo atual: 892.09
# Geração: 522, Melhor custo atual: 892.09
# Geração: 523, Melhor custo atual: 892.09
# Geração: 524, Melhor custo atual: 892.09
# Geração: 525, Melhor custo atual: 892.09
# Geração: 526, Melhor custo atual: 892.09
# Geração: 527, Melhor custo atual: 892.09
# Geração: 528, Melhor custo atual: 892.09
# Geração: 529, Melhor custo atual: 892.09
# Geração: 530, Melhor custo atual: 892.09
# Geração: 531, Melhor custo atual: 892.09
# Geração: 532, Melhor custo atual: 892.09
# Geração: 533, Melhor custo atual: 892.09
# Geração: 534, Melhor custo atual: 892.09
# Geração: 535, Melhor custo atual: 891.35
# Geração: 536, Melhor custo atual: 875.27
# Geração: 537, Melhor custo atual: 875.27
# Geração: 538, Melhor custo atual: 875.27
# Geração: 539, Melhor custo atual: 875.27
# Geração: 540, Melhor custo atual: 875.27
# Geração: 541, Melhor custo atual: 875.27
# Geração: 542, Melhor custo atual: 875.27
# Geração: 543, Melhor custo atual: 875.27
# Geração: 544, Melhor custo atual: 875.27
# Geração: 545, Melhor custo atual: 875.27
# Geração: 546, Melhor custo atual: 875.27
# Geração: 547, Melhor custo atual: 875.27
# Geração: 548, Melhor custo atual: 875.27
# Geração: 549, Melhor custo atual: 875.27
# Geração: 550, Melhor custo atual: 875.27
# Geração: 551, Melhor custo atual: 875.27
# Geração: 552, Melhor custo atual: 875.27
# Geração: 553, Melhor custo atual: 875.27
# Geração: 554, Melhor custo atual: 874.88
# Geração: 555, Melhor custo atual: 874.88
# Geração: 556, Melhor custo atual: 874.88
# Geração: 557, Melhor custo atual: 874.88
# Geração: 558, Melhor custo atual: 874.88
# Geração: 559, Melhor custo atual: 874.88
# Geração: 560, Melhor custo atual: 874.88
# Geração: 561, Melhor custo atual: 874.88
# Geração: 562, Melhor custo atual: 874.88
# Geração: 563, Melhor custo atual: 874.88
# Geração: 564, Melhor custo atual: 874.88
# Geração: 565, Melhor custo atual: 874.88
# Geração: 566, Melhor custo atual: 874.88
# Geração: 567, Melhor custo atual: 874.88
# Geração: 568, Melhor custo atual: 874.88
# Geração: 569, Melhor custo atual: 874.88
# Geração: 570, Melhor custo atual: 874.88
# Geração: 571, Melhor custo atual: 874.88
# Geração: 572, Melhor custo atual: 874.88
# Geração: 573, Melhor custo atual: 874.88
# Geração: 574, Melhor custo atual: 874.88
# Geração: 575, Melhor custo atual: 873.61
# Geração: 576, Melhor custo atual: 873.61
# Geração: 577, Melhor custo atual: 873.61
# Geração: 578, Melhor custo atual: 873.61
# Geração: 579, Melhor custo atual: 873.61
# Geração: 580, Melhor custo atual: 873.61
# Geração: 581, Melhor custo atual: 873.61
# Geração: 582, Melhor custo atual: 873.61
# Geração: 583, Melhor custo atual: 873.61
# Geração: 584, Melhor custo atual: 873.61
# Geração: 585, Melhor custo atual: 873.61
# Geração: 586, Melhor custo atual: 873.61
# Geração: 587, Melhor custo atual: 873.61
# Geração: 588, Melhor custo atual: 873.61
# Geração: 589, Melhor custo atual: 873.61
# Geração: 590, Melhor custo atual: 873.61
# Geração: 591, Melhor custo atual: 873.61
# Geração: 592, Melhor custo atual: 873.61
# Geração: 593, Melhor custo atual: 873.61
# Geração: 594, Melhor custo atual: 873.61
# Geração: 595, Melhor custo atual: 873.61
# Geração: 596, Melhor custo atual: 873.61
# Geração: 597, Melhor custo atual: 873.61
# Geração: 598, Melhor custo atual: 873.61
# Geração: 599, Melhor custo atual: 873.61
# Geração: 600, Melhor custo atual: 873.61
# Geração: 601, Melhor custo atual: 873.61
# Geração: 602, Melhor custo atual: 873.61
# Geração: 603, Melhor custo atual: 873.61
# Geração: 604, Melhor custo atual: 873.61
# Geração: 605, Melhor custo atual: 873.61
# Geração: 606, Melhor custo atual: 873.61
# Geração: 607, Melhor custo atual: 873.61
# Geração: 608, Melhor custo atual: 873.61
# Geração: 609, Melhor custo atual: 873.61
# Geração: 610, Melhor custo atual: 873.61
# Geração: 611, Melhor custo atual: 873.61
# Geração: 612, Melhor custo atual: 873.61
# Geração: 613, Melhor custo atual: 873.61
# Geração: 614, Melhor custo atual: 873.61
# Geração: 615, Melhor custo atual: 873.61
# Geração: 616, Melhor custo atual: 873.61
# Geração: 617, Melhor custo atual: 873.61
# Geração: 618, Melhor custo atual: 873.61
# Geração: 619, Melhor custo atual: 873.61
# Geração: 620, Melhor custo atual: 873.61
# Geração: 621, Melhor custo atual: 873.61
# Geração: 622, Melhor custo atual: 873.61
# Geração: 623, Melhor custo atual: 873.61
# Geração: 624, Melhor custo atual: 873.61
# Geração: 625, Melhor custo atual: 873.61
# Geração: 626, Melhor custo atual: 873.61
# Geração: 627, Melhor custo atual: 873.61
# Geração: 628, Melhor custo atual: 873.61
# Geração: 629, Melhor custo atual: 873.61
# Geração: 630, Melhor custo atual: 873.61
# Geração: 631, Melhor custo atual: 873.61
# Geração: 632, Melhor custo atual: 873.61
# Geração: 633, Melhor custo atual: 873.61
# Geração: 634, Melhor custo atual: 873.61
# Geração: 635, Melhor custo atual: 873.61
# Geração: 636, Melhor custo atual: 873.61
# Geração: 637, Melhor custo atual: 873.61
# Geração: 638, Melhor custo atual: 873.61
# Geração: 639, Melhor custo atual: 873.61
# Geração: 640, Melhor custo atual: 873.61
# Geração: 641, Melhor custo atual: 873.61
# Geração: 642, Melhor custo atual: 873.61
# Geração: 643, Melhor custo atual: 873.61
# Geração: 644, Melhor custo atual: 873.61
# Geração: 645, Melhor custo atual: 873.61
# Geração: 646, Melhor custo atual: 873.61
# Geração: 647, Melhor custo atual: 873.61
# Geração: 648, Melhor custo atual: 873.61
# Geração: 649, Melhor custo atual: 873.61
# Geração: 650, Melhor custo atual: 873.61
# Geração: 651, Melhor custo atual: 873.61
# Geração: 652, Melhor custo atual: 873.61
# Geração: 653, Melhor custo atual: 873.61
# Geração: 654, Melhor custo atual: 873.61
# Geração: 655, Melhor custo atual: 873.61
# Geração: 656, Melhor custo atual: 873.61
# Geração: 657, Melhor custo atual: 873.61
# Geração: 658, Melhor custo atual: 873.61
# Geração: 659, Melhor custo atual: 873.61
# Geração: 660, Melhor custo atual: 873.61
# Geração: 661, Melhor custo atual: 873.61
# Geração: 662, Melhor custo atual: 873.61
# Geração: 663, Melhor custo atual: 873.61
# Geração: 664, Melhor custo atual: 873.61
# Geração: 665, Melhor custo atual: 873.61
# Geração: 666, Melhor custo atual: 873.61
# Geração: 667, Melhor custo atual: 873.61
# Geração: 668, Melhor custo atual: 873.61
# Geração: 669, Melhor custo atual: 873.61
# Geração: 670, Melhor custo atual: 873.61
# Geração: 671, Melhor custo atual: 873.61
# Geração: 672, Melhor custo atual: 873.61
# Geração: 673, Melhor custo atual: 873.61
# Geração: 674, Melhor custo atual: 873.61
# Geração: 675, Melhor custo atual: 873.61
# Geração: 676, Melhor custo atual: 873.61
# Geração: 677, Melhor custo atual: 873.61
# Geração: 678, Melhor custo atual: 873.61
# Geração: 679, Melhor custo atual: 873.61
# Geração: 680, Melhor custo atual: 873.61
# Geração: 681, Melhor custo atual: 873.61
# Geração: 682, Melhor custo atual: 873.61
# Geração: 683, Melhor custo atual: 873.61
# Geração: 684, Melhor custo atual: 873.61
# Geração: 685, Melhor custo atual: 873.61
# Geração: 686, Melhor custo atual: 873.61
# Geração: 687, Melhor custo atual: 873.61
# Geração: 688, Melhor custo atual: 873.61
# Geração: 689, Melhor custo atual: 873.61
# Geração: 690, Melhor custo atual: 873.61
# Geração: 691, Melhor custo atual: 873.61
# Geração: 692, Melhor custo atual: 873.61
# Geração: 693, Melhor custo atual: 873.61
# Geração: 694, Melhor custo atual: 873.61
# Geração: 695, Melhor custo atual: 873.61
# Geração: 696, Melhor custo atual: 873.61
# Geração: 697, Melhor custo atual: 873.61
# Geração: 698, Melhor custo atual: 873.61
# Geração: 699, Melhor custo atual: 873.61
# Geração: 700, Melhor custo atual: 873.61
# Geração: 701, Melhor custo atual: 873.61
# Geração: 702, Melhor custo atual: 873.61
# Geração: 703, Melhor custo atual: 873.61
# Geração: 704, Melhor custo atual: 873.61
# Geração: 705, Melhor custo atual: 873.61
# Geração: 706, Melhor custo atual: 873.61
# Geração: 707, Melhor custo atual: 873.61
# Geração: 708, Melhor custo atual: 873.61
# Geração: 709, Melhor custo atual: 873.61
# Geração: 710, Melhor custo atual: 873.61
# Geração: 711, Melhor custo atual: 873.61
# Geração: 712, Melhor custo atual: 873.61
# Geração: 713, Melhor custo atual: 873.61
# Geração: 714, Melhor custo atual: 873.61
# Geração: 715, Melhor custo atual: 873.61
# Geração: 716, Melhor custo atual: 873.61
# Geração: 717, Melhor custo atual: 873.61
# Geração: 718, Melhor custo atual: 873.61
# Geração: 719, Melhor custo atual: 873.61
# Geração: 720, Melhor custo atual: 873.61
# Geração: 721, Melhor custo atual: 873.61
# Geração: 722, Melhor custo atual: 873.61
# Geração: 723, Melhor custo atual: 873.61
# Geração: 724, Melhor custo atual: 873.61
# Geração: 725, Melhor custo atual: 873.61
# Geração: 726, Melhor custo atual: 873.61
# Geração: 727, Melhor custo atual: 873.61
# Geração: 728, Melhor custo atual: 873.61
# Geração: 729, Melhor custo atual: 873.61
# Geração: 730, Melhor custo atual: 873.61
# Geração: 731, Melhor custo atual: 873.61
# Geração: 732, Melhor custo atual: 873.61
# Geração: 733, Melhor custo atual: 873.61
# Geração: 734, Melhor custo atual: 873.61
# Geração: 735, Melhor custo atual: 873.61
# Geração: 736, Melhor custo atual: 873.61
# Geração: 737, Melhor custo atual: 873.61
# Geração: 738, Melhor custo atual: 873.61
# Geração: 739, Melhor custo atual: 873.61
# Geração: 740, Melhor custo atual: 873.61
# Geração: 741, Melhor custo atual: 873.61
# Geração: 742, Melhor custo atual: 873.61
# Geração: 743, Melhor custo atual: 873.61
# Geração: 744, Melhor custo atual: 873.61
# Geração: 745, Melhor custo atual: 873.61
# Geração: 746, Melhor custo atual: 873.61
# Geração: 747, Melhor custo atual: 873.61
# Geração: 748, Melhor custo atual: 873.61
# Geração: 749, Melhor custo atual: 873.61
# Geração: 750, Melhor custo atual: 873.61
# Geração: 751, Melhor custo atual: 873.61
# Geração: 752, Melhor custo atual: 873.61
# Geração: 753, Melhor custo atual: 873.61
# Geração: 754, Melhor custo atual: 873.61
# Geração: 755, Melhor custo atual: 873.61
# Geração: 756, Melhor custo atual: 873.61
# Geração: 757, Melhor custo atual: 873.61
# Geração: 758, Melhor custo atual: 873.61
# Geração: 759, Melhor custo atual: 873.61
# Geração: 760, Melhor custo atual: 873.61
# Geração: 761, Melhor custo atual: 873.61
# Geração: 762, Melhor custo atual: 873.61
# Geração: 763, Melhor custo atual: 873.61
# Geração: 764, Melhor custo atual: 873.61
# Geração: 765, Melhor custo atual: 873.61
# Geração: 766, Melhor custo atual: 873.61
# Geração: 767, Melhor custo atual: 873.61
# Geração: 768, Melhor custo atual: 873.61
# Geração: 769, Melhor custo atual: 873.61
# Geração: 770, Melhor custo atual: 873.61
# Geração: 771, Melhor custo atual: 873.61
# Geração: 772, Melhor custo atual: 873.61
# Geração: 773, Melhor custo atual: 873.61
# Geração: 774, Melhor custo atual: 873.61
# Geração: 775, Melhor custo atual: 873.61
# Melhor Rota Encontrada:
# Rota: [(115, 78.0, 32.0), (109, 74.0, 29.0), (107, 74.0, 20.0), (106, 74.0, 16.0), (114, 78.0, 10.0), (118, 79.0, 10.0), (124, 81.0, 17.0), (125, 84.0, 20.0), (113, 77.0, 21.0), (108, 74.0, 24.0), (86, 41.0, 36.0), (72, 34.0, 38.0), (59, 28.0, 40.0), (23, 15.0, 37.0), (9, 5.0, 31.0), (3, 0.0, 27.0), (2, 0.0, 26.0), (8, 5.0, 25.0), (33, 18.0, 25.0), (62, 32.0, 26.0), (65, 33.0, 26.0), (69, 34.0, 26.0), (82, 41.0, 23.0), (87, 48.0, 22.0), (92, 56.0, 25.0), (94, 57.0, 25.0), (99, 64.0, 22.0), (102, 71.0, 16.0), (105, 74.0, 12.0), (121, 80.0, 10.0), (130, 84.0, 6.0), (123, 80.0, 5.0), (112, 74.0, 6.0), (74, 34.0, 5.0), (53, 25.0, 9.0), (45, 25.0, 11.0), (34, 18.0, 27.0), (35, 18.0, 29.0), (52, 25.0, 29.0), (51, 25.0, 28.0), (50, 25.0, 26.0), (49, 25.0, 24.0), (32, 18.0, 23.0), (20, 15.0, 19.0), (6, 5.0, 13.0), (12, 5.0, 8.0), (13, 8.0, 0.0), (5, 2.0, 0.0), (1, 0.0, 13.0), (7, 5.0, 19.0), (21, 15.0, 25.0), (37, 18.0, 33.0), (38, 18.0, 35.0), (39, 18.0, 37.0), (40, 18.0, 39.0), (43, 18.0, 44.0), (44, 18.0, 45.0), (42, 18.0, 42.0), (41, 18.0, 41.0), (57, 28.0, 30.0), (56, 28.0, 28.0), (75, 35.0, 17.0), (68, 34.0, 15.0), (64, 33.0, 15.0), (54, 28.0, 16.0), (46, 25.0, 15.0), (28, 18.0, 15.0), (27, 18.0, 13.0), (19, 15.0, 13.0), (17, 12.0, 10.0), (16, 11.0, 10.0), (15, 10.0, 10.0), (14, 9.0, 10.0), (18, 12.0, 5.0), (25, 15.0, 8.0), (26, 18.0, 11.0), (29, 18.0, 17.0), (30, 18.0, 19.0), (31, 18.0, 21.0), (48, 25.0, 23.0), (47, 25.0, 22.0), (55, 28.0, 20.0), (77, 38.0, 16.0), (78, 38.0, 20.0), (70, 34.0, 29.0), (66, 33.0, 29.0), (63, 32.0, 31.0), (67, 33.0, 31.0), (71, 34.0, 31.0), (76, 35.0, 31.0), (80, 38.0, 34.0), (79, 38.0, 30.0), (81, 40.0, 22.0), (89, 48.0, 6.0), (93, 57.0, 12.0), (98, 63.0, 6.0), (100, 71.0, 11.0), (101, 71.0, 13.0), (88, 48.0, 27.0), (83, 41.0, 32.0), (84, 41.0, 34.0), (85, 41.0, 35.0), (73, 34.0, 41.0), (60, 28.0, 43.0), (61, 28.0, 47.0), (24, 15.0, 43.0), (11, 5.0, 43.0), (4, 0.0, 39.0), (10, 5.0, 37.0), (22, 15.0, 31.0), (36, 18.0, 31.0), (58, 28.0, 34.0), (90, 51.0, 45.0), (91, 51.0, 47.0), (95, 57.0, 44.0), (96, 61.0, 45.0), (97, 61.0, 47.0), (104, 71.0, 47.0), (103, 71.0, 45.0), (111, 74.0, 39.0), (110, 74.0, 35.0), (119, 79.0, 33.0), (116, 78.0, 35.0), (120, 79.0, 37.0), (117, 78.0, 39.0), (122, 80.0, 41.0), (129, 84.0, 38.0), (128, 84.0, 34.0), (131, 107.0, 27.0), (126, 84.0, 24.0), (127, 84.0, 29.0)]
# Aptidão: 873.6130596861819
